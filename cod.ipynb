# %%
pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\Stefan\Documents\ssnombacter\pyproj\my_env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import skew
from scipy.stats import kurtosis
from scipy.stats import variation
import matplotlib.dates as mdates
from matplotlib.pyplot import figure

figure(figsize=(15, 6), dpi=80)

# %%
dat=pd.read_csv('new.csv')
da1=pd.read_csv('1.csv')
# Out:
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_21212\2464859976.py:2: DtypeWarning: Columns (42) have mixed types. Specify dtype option on import or set low_memory=False.
#   da1=pd.read_csv('1.csv')

# %%
su=da1.bra

# %%
su
# Out:
# array([-0.97098277, -0.99870639, -1.0009424 , ..., -0.37882083,
#        -0.38037354, -0.37980278])

# %%
su=np.array(su)

# %%
su = su[~np.isnan(su)]

# %%
import pandas as pd

df = pd.DataFrame()

# %%
tan=np.array(tan)
tap=np.array(tap)

# %%
df['ta']=tan
df['tp']=tap

# %%
df=df.dropna()
df=df.drop_duplicates()

# %%
df=df.sort_values(by=['ta'])

# %%
figure(figsize=(30, 20), dpi=80)



plt.plot(df.ta,df.tp,"+")

# %%
figure(figsize=(30, 20), dpi=80)
plt.plot((np.convolve(su, np.ones(100), 'same') / 30),"+")

# %%
asat
# Out:
# 0                  0
# 1         2.9180882e
# 2         2.5952506e
# 3         4.1580344e
# 4         3.3594958e
#              ...
# 199996           NaN
# 199997           NaN
# 199998           NaN
# 199999           NaN
# 200000           NaN
# Name: asat, Length: 200001, dtype: object

# %%
figure(figsize=(30, 20), dpi=80)



plt.plot(df.ta[10000:18000]+1,df.tp50[10000:18000],"-")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [208], in <cell line: 5>()
#       1 figure(figsize=(30, 20), dpi=80)
# ----> 5 plt.plot(df.ta[10000:18000]+1,df.tp50[10000:18000],"-")
#
# File ~\Documents\ssnombacter\pyproj\my_env\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'tp50'

# %%
len(ta)
# Out:
# 31981

# %%
figure(figsize=(30, 6), dpi=80)
#plt.plot(temp[11000:19000],pot[11000:19000],"-")

#plt.plot(argon_t[11000:19000],argon_p[11000:19000],"-")
#plt.plot(argon_t_100[11000:19000],argon_p[11000:19000],"-")
plt.plot(t[11000:19000],p1[11000:19000],"-")
plt.plot(t1[11000:19000],p1[11000:19000],"-")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [111], in <cell line: 6>()
#       1 figure(figsize=(30, 6), dpi=80)
#       2 #plt.plot(temp[11000:19000],pot[11000:19000],"-")
#       3
#       4 #plt.plot(argon_t[11000:19000],argon_p[11000:19000],"-")
#       5 #plt.plot(argon_t_100[11000:19000],argon_p[11000:19000],"-")
# ----> 6 plt.plot(t[11000:19000],p1[11000:19000],"-")
#       7 plt.plot(t1[11000:19000],p1[11000:19000],"-")
#
# NameError: name 't' is not defined

# %%
plt.plot(rul2t[1500-500:1500+500],p2[1500-500:1500+500],"-")

# %%
len(rul2t)
# Out:
# 31981

# %%
rul2t[1500]
# Out:
# 29.86914211

# %%
figure(figsize=(15, 6), dpi=80)
plt.plot(rul2t[1100:1900],p2[1100:1900],"-")

# %%
figure(figsize=(15, 6), dpi=80)
plt.plot(temp[11000:19000],pot[11000:19000],"-")
plt.plot(avg_t_100[11000:19000],pot[11000:19000],"-")
plt.plot(avg_t_200[11000:19000],pot[11000:19000],"-")

# %%
len(temp)/2
# Out:
# 15990.5

# %%
temp[11000]
# Out:
# 76.656729

# %%
data  = pd.read_csv('data.csv')

# %%
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=360))
#plt.plot(np.flip(data.date),np.flip(data.sold))
plt.plot(data.date,(np.convolve(data.hidro, np.ones(30), 'same') / 30))
plt.plot(data.date,(np.convolve(data.nuclear, np.ones(30), 'same') / 30))
plt.gcf().autofmt_xdate()
plt.xlabel("Date")
plt.ylabel("MW")
plt.tight_layout()

# %%
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=360))
plt.plot(data.date,data.sold)
plt.plot(data.date,(np.convolve(data.sold, np.ones(30), 'same') / 30))
plt.gcf().autofmt_xdate()
plt.xlabel("Date")
plt.ylabel("MW")
plt.tight_layout()
plt.savefig('plot_sold.png')

# %%
print(data.carbune.mean())
print(np.std(data.carbune))
print(skew(data.carbune))
print(kurtosis(data.carbune))
print(variation(data.carbune))
print(data.carbune.min())
print(data.carbune.max())

plt.hist(data.carbune, bins ='auto')

plt.xlabel("MW")
plt.ylabel("Frequency")
plt.savefig('hist_coal.png')
# Out:
# 2143.077890408339
# 764.8852307281926
# 0.28857694464969263
# -0.6093152882244777
# 0.35690967376946453
# 295
# 4559

# %%
print(data.hidro.mean())
print(np.std(data.hidro))
print(skew(data.hidro))
print(kurtosis(data.hidro))
print(variation(data.hidro))
print(data.hidro.min())
print(data.hidro.max())

plt.hist(data.hidro, bins ='auto')

plt.xlabel("MW")
plt.ylabel("Frequency")
plt.savefig('hist_hidro.png')
# Out:
# 1859.6828918427848
# 720.1679119542634
# 0.25252366016259675
# -0.3912477720720262
# 0.387253071538793
# 88
# 4581

# %%
print(data.hidrocarburi.mean())
print(np.std(data.hidrocarburi))
print(skew(data.hidrocarburi))
print(kurtosis(data.hidrocarburi))
print(variation(data.hidrocarburi))
print(data.hidrocarburi.min())
print(data.hidrocarburi.max())

plt.hist(data.hidrocarburi, bins ='auto')

plt.xlabel("MW")
plt.ylabel("Frequency")
plt.savefig('hist_hidrocarburi.png')
# Out:
# 1057.8536865257722
# 471.47491157885753
# 0.21481975762037547
# -0.8407793940032509
# 0.4456900964511325
# 130
# 2494

# %%
print(data.nuclear.mean())
print(np.std(data.nuclear))
print(skew(data.nuclear))
print(kurtosis(data.nuclear))
print(variation(data.nuclear))
print(data.nuclear.min())
print(data.nuclear.max())

plt.hist(data.nuclear, bins ='auto')

plt.xlabel("MW")
plt.ylabel("Frequency")
plt.savefig('hist_nuclear.png')
# Out:
# 1319.4954575882184
# 224.66719663319262
# -2.4811728040939287
# 4.688131743127135
# 0.17026750288617185
# 0
# 1443

# %%
print(data.eolian.mean())
print(np.std(data.eolian))
print(skew(data.eolian))
print(kurtosis(data.eolian))
print(variation(data.eolian))
print(data.eolian.min())
print(data.eolian.max())

plt.hist(data.eolian, bins ='auto')
plt.xlabel("MW")
plt.ylabel("Frequency")
plt.savefig('hist_eolian.png')
# Out:
# 488.8975327531797
# 618.1965275753033
# 1.4953378155174024
# 1.497923193479397
# 1.2644705406754433
# -25
# 2790

# %%
print(data.fotovolt.mean())
print(np.std(data.fotovolt))
print(skew(data.fotovolt))
print(kurtosis(data.fotovolt))
print(variation(data.fotovolt))
print(data.fotovolt.min())
print(data.fotovolt.max())


plt.hist(data.fotovolt, bins ='auto')
plt.xlabel("MW")
plt.ylabel("Frequency")
plt.savefig('hist_foto.png')
# Out:
# 80.07301329253131
# 175.9276914549568
# 2.3235457399884005
# 4.405352547813109
# 2.197090932649667
# -2
# 864

# %%
print(data.biomasa.mean())
print(np.std(data.biomasa))
print(skew(data.biomasa))
print(kurtosis(data.biomasa))
print(variation(data.biomasa))
print(data.biomasa.min())
print(data.biomasa.max())

plt.hist(data.biomasa, bins ='auto')

plt.xlabel("MW")
plt.ylabel("Frequency")
plt.savefig('hist_bio.png')
# Out:
# 30.959452997991775
# 28.268861101782747
# 0.04538635808982437
# -1.6258826330753637
# 0.9130930415216458
# 0
# 107

# %%
print(data.sold.mean())
print(np.std(data.sold))
print(skew(data.sold))
print(kurtosis(data.sold))
print(variation(data.sold))
print(data.sold.min())
print(data.sold.max())


plt.hist(data.sold, bins ='auto')
plt.xlabel("MW")
plt.ylabel("Frequency")
plt.savefig('hist_sold.png')
# Out:
# -273.51104523285835
# 595.8583981588484
# 0.4696109066087002
# 0.5091065323723996
# -2.178553329177453
# -2053
# 2327

# %%
consum = np.flip(data.consum)
dat = np.flip(data.date)

# %%
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=90))
#plt.plot(np.flip(data.date),np.flip(data.sold))
plt.plot(dat,consum)
plt.gcf().autofmt_xdate()
plt.xlabel("Date")
plt.ylabel("MW")
plt.tight_layout()

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pmdarima as pm
from sklearn.metrics import mean_squared_error
import statsmodels as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.tsa.stattools as ts
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.seasonal import seasonal_decompose

# fix random seed for reproducibility
np.random.seed(7)

df = pd.read_csv('data.csv')

# %%
df=df[::-1]
df_avg=df_avg[::-1]

# %%
df.head()
df_avg.head()
# Out:
#             date   consum_avg
# 1398  07/03/2019  8502.000000
# 1397  08/03/2019  7925.000000
# 1396  09/03/2019  7450.666667
# 1395  10/03/2019  7164.750000
# 1394  11/03/2019  7186.000000

# %%
y = df_avg.set_index(['date'])
y.head(5)
# Out:
#              consum_avg
# date
# 07/03/2019  8502.000000
# 08/03/2019  7925.000000
# 09/03/2019  7450.666667
# 10/03/2019  7164.750000
# 11/03/2019  7186.000000

# %%
plt.plot(df_avg.consum_avg)

# %%
dataset=y

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition=seasonal_decompose(dataset[:100], model='additive', period=7)
trend=decomposition.trend
seasonal=decomposition.seasonal
residual=decomposition.resid
plt.subplot(221)
plt.plot(dataset,color='#ff0000', label='Series')
plt.legend(loc='best')
plt.subplot(222)
plt.plot(trend,color='#1100ff', label='Trend')
plt.legend(loc='best')
plt.tight_layout()
plt.subplot(223)
plt.plot(residual,color='#00ff1a', label='Residual')
plt.legend(loc='best')
plt.tight_layout()
plt.subplot(224)
plt.plot(seasonal,color='#de00ff', label='Seasonality')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
plt.plot(dataset)
plt.xlabel('Days')
plt.ylabel('Kilowatts')
plt.title("Kilowatts consumed per day")
plt.show()

# %%
train_df=dataset[:1000]
train_df
# Out:
#              consum_avg
# date
# 07/03/2019  8502.000000
# 08/03/2019  7925.000000
# 09/03/2019  7450.666667
# 10/03/2019  7164.750000
# 11/03/2019  7186.000000
# ...                 ...
# 26/04/2021  6801.714286
# 27/04/2021  6726.142857
# 27/04/2021  6776.142857
# 28/04/2021  6822.142857
# 29/04/2021  6832.428571
#
# [1000 rows x 1 columns]

# %%
plot_acf(train_df, lags=10, zero=False); #7

# %%
plot_pacf(train_df, lags=10, zero=False); #7
# Out:
# C:\Users\Stefan\Documents\SSNOMBACTER\pyproj\my_env\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
test_df=dataset.consum[1000:1399]

# %%
window_size = 7

numbers_series = pd.Series(train_df)
windows = numbers_series.rolling(window_size)
moving_averages = windows.mean()

moving_averages_list = moving_averages.tolist()
ts7 = moving_averages_list[window_size - 1:]
ts7=np.array(ts7)
print(ts7)
# Out:
# [6911.14285714 6811.42857143 6913.42857143 7059.         7224.
#  7076.85714286 7037.71428571 6995.42857143 6865.28571429 6914.57142857
#  6878.14285714 6856.71428571 6962.42857143 6924.71428571 6833.28571429
#  6755.71428571 6734.42857143 6732.85714286 6735.71428571 6824.42857143
#  6925.42857143 6964.85714286 6841.         6706.28571429 6774.57142857
#  6748.71428571 6687.28571429 6858.71428571 7032.28571429 7045.85714286
#  6773.         6685.         6725.14285714 6711.85714286 6764.42857143
#  6894.57142857 6963.85714286 6996.42857143 6813.14285714 6902.71428571
#  6936.57142857 6900.85714286 6937.71428571 7166.28571429 7223.14285714
#  7206.42857143 6989.57142857 6988.42857143 6953.85714286 6899.85714286
#  6868.71428571 6795.57142857 6714.71428571 6621.57142857 6311.42857143
#  5949.42857143 5712.71428571 5573.14285714 5630.71428571 5679.85714286
#  5671.71428571 5933.28571429 6066.57142857 6222.28571429 6374.14285714
# ...

# %%
n1=math.nan
n7=np.array([n1,n1,n1,n1,n1,n1,n1])
ts7=np.concatenate([n7,ts7])
plt.plot(train_df)
plt.plot(ts7)
plt.xlabel('Days')
plt.ylabel('Kilowatts')
plt.title("7-day Simple Moving Average")
plt.show()

# %%
#Dickey-Fuller Test
result = ts.adfuller(train_df, 0)
result
# Out:
# (-4.492184915037423,
#  0.00020313350009443045,
#  0,
#  999,
#  {'1%': -3.4369127451400474,
#   '5%': -2.864437475834273,
#   '10%': -2.568312754566378},
#  12964.685866153257)

# %%
Arima_model=pm.auto_arima(train_df, start_p=0, start_q=0, max_p=2, max_q=2, 
                          start_P=0, start_Q=0, max_P=2, max_Q=2, m=7, stepwise=True, seasonal=True,
                          information_criterion='aic', trace=True,  error_action='warn', suppress_warnings=True,
                          random_state = 20, n_fits=30)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=12984.704, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=12882.382, Time=0.60 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=12703.782, Time=0.60 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=12982.813, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[7] intercept   : AIC=12964.724, Time=0.07 sec
#  ARIMA(0,1,1)(1,0,1)[7] intercept   : AIC=12641.385, Time=0.75 sec
#  ARIMA(0,1,1)(1,0,0)[7] intercept   : AIC=12876.485, Time=0.34 sec
#  ARIMA(0,1,1)(2,0,1)[7] intercept   : AIC=12638.636, Time=1.77 sec
#  ARIMA(0,1,1)(2,0,0)[7] intercept   : AIC=12803.504, Time=0.84 sec
#  ARIMA(0,1,1)(2,0,2)[7] intercept   : AIC=inf, Time=3.21 sec
#  ARIMA(0,1,1)(1,0,2)[7] intercept   : AIC=12639.784, Time=2.37 sec
#  ARIMA(0,1,0)(2,0,1)[7] intercept   : AIC=12681.157, Time=1.32 sec
#  ARIMA(1,1,1)(2,0,1)[7] intercept   : AIC=12640.618, Time=1.99 sec
# ...

# %%
Arima_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...
# Dep. Variable:                                   y   No. Observations:                 1000
# Model:             SARIMAX(2, 1, 2)x(2, 0, [1], 7)   Log Likelihood               -6286.186
# Date:                             Tue, 29 Mar 2022   AIC                          12588.372
# Time:                                     22:01:39   BIC                          12627.626
# Sample:                                          0   HQIC                         12603.292
#                                             - 1000
# Covariance Type:                               opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2666      0.034     -7.835      0.000      -0.333      -0.200
# ...

# %%
prediction=pd.DataFrame(Arima_model.predict(n_periods=50), index=test_df[:50])
prediction=np.array(prediction)

# %%
prediction=prediction.reshape(50,-1)
prediction
# Out:
# array([[6829.50981909],
#        [6947.00368238],
#        [6986.70463805],
#        [7065.2617917 ],
#        [7049.0431991 ],
#        [6951.80471701],
#        [7067.92119395],
#        [7091.51182109],
#        [7148.32443877],
#        [7141.70895523],
#        [7178.63762936],
#        [7177.40667947],
#        [7137.80991435],
#        [7162.48315126],
#        [7178.59781128],
#        [7182.44504207],
#        [7168.15698385],
#        [7171.35707928],
#        [7179.6923443 ],
#        [7175.99398023],
#        [7165.59894744],
#        [7171.52038115],
#        [7170.2596697 ],
#        [7162.79728478],
#        [7158.23097153],
#        [7164.78275016],
#        [7168.10106769],
#        [7159.20447381],
#        [7159.84080071],
#        [7162.20071114],
#        [7160.27076474],
#        [7156.52656615],
#        [7159.21443335],
#        [7161.88441069],
#        [7158.66801762],
#        [7157.5185045 ],
#        [7160.13277579],
#        [7160.4997766 ],
# ...

# %%
plt.plot(test_df[:50])
plt.plot(prediction)
plt.xlabel('Days')
plt.ylabel('Kilowatts')
plt.title("Test vs. Prediction")
plt.show()

# %%
import os
from datetime import datetime
import pandas as pd
import numpy as np
from matplotlib import pylab as plt
from matplotlib import pyplot
from IPython.core.display import display, HTML
from statsmodels.tsa.stattools import adfuller
from sklearn.linear_model import LinearRegression
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.linear_model import LinearRegression
from statsmodels.tsa.api import SimpleExpSmoothing, Holt, ExponentialSmoothing
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
from functools import partial
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import (TimeSeriesSplit, train_test_split, 
                                     cross_val_score)
from sklearn.preprocessing import StandardScaler, scale
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK, STATUS_FAIL
import xgboost as xgb
from statsmodels.tsa.stattools import pacf, acf

display(HTML("<style>.container { width:100% !important; }</style>"))
plt.style.use('ggplot')
# Out:
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_9308\1671388292.py:7: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# C:\Users\Stefan\Documents\SSNOMBACTER\pyproj\my_env\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# <style>.container { width:100% !important; }</style>

# %%
DATE_FORMAT = "%Y-%m-%d"
ENERGY_FILE = 'data.csv'

data = pd.read_csv(os.path.join(os.getcwd(), ENERGY_FILE))
data["date"] = data["date"].apply(lambda dates: datetime.strptime(dates, DATE_FORMAT))
data.set_index("date", drop=True, inplace=True)
data.head()
data = data.drop_duplicates()

# %%
# define which load to use for forecasting and other general constants
carbune = "carbune"
hidro = "hidro"
hidrocarburi ="hidrocarburi"
nuclear= "nuclear"
eolian="eolian"
fotovolt = "fotovolt"
biomasa="biomasa"
sold="sold"

productie = "productie"
consum="consum"
FREQ = "1D" # frequency of the time series

data_carbune = pd.DataFrame()
data_hidro = pd.DataFrame()
data_hidrocarburi = pd.DataFrame()
data_nuclear = pd.DataFrame()
data_eolian = pd.DataFrame()
data_fotovolt = pd.DataFrame()
data_biomasa = pd.DataFrame()
data_sold = pd.DataFrame()

data_productie = pd.DataFrame()
data_consum = pd.DataFrame()






data_carbune["energy"] = data[carbune].dropna()
data_hidro["energy"] = data[hidro].dropna()
data_hidrocarburi["energy"] = data[hidrocarburi].dropna()
data_nuclear["energy"] = data[nuclear].dropna()
data_eolian["energy"] = data[eolian].dropna()
data_fotovolt["energy"] = data[fotovolt].dropna()
data_biomasa["energy"] = data[biomasa].dropna()
data_sold["energy"] = data[sold].dropna()

data_productie["energy"] = data[productie].dropna()
data_consum["energy"] = data[consum].dropna()

# %%
data_fotovolt[data_fotovolt < 0] = 0
data_eolian[data_eolian < 0] = 0

# %%
plt.plot(data_consum)

# %%
class TargetTransformer:
    """
    Perform some transformation on the time series
    data in order to make the model more performant and
    avoid non-stationary effects.
    """
        
    def __init__(self, log=False, detrend=False, diff=False):
        
        self.trf_log = log
        self.trf_detrend = detrend
        self.trend = pd.Series(dtype=np.float64)
    
    def transform(self, index, values):
        """
        Perform log transformation to the target time series

        :param index: the index for the resulting series
        :param values: the values of the initial series

        Return:
            transformed pd.Series
        """
        res = pd.Series(index=index, data=values)

        if self.trf_detrend:
            self.trend = TargetTransformer.get_trend(res) - np.mean(res.values)
            res = res.subtract(self.trend)
            
        if self.trf_log:
            res = pd.Series(index=index, data=np.log(res.values))
        
        return res
    
    def inverse(self, index, values):
        """
        Go back to the original time series values

        :param index: the index for the resulting series
        :param values: the values of series to be transformed back

        Return:
            inverse transformed pd.Series
        """        
        res = pd.Series(index=index, data=values)
        
        if self.trf_log:
            res = pd.Series(index=index, data=np.exp(values))
        try:
            if self.trf_detrend:
                assert len(res.index) == len(self.trend.index)                
                res = res + self.trend
                
        except AssertionError:
            print("Use a different transformer for each target to transform")
            
        return res
    
    @staticmethod
    def get_trend(data):
        """
        Get the linear trend on the data which makes the time
        series not stationary
        """
        n = len(data.index)
        X = np.reshape(np.arange(0, n), (n, 1))
        y = np.array(data)
        model = LinearRegression()
        model.fit(X, y)
        trend = model.predict(X)
        return pd.Series(index=data.index, data=trend)

# %%
def ts_analysis_plots(data, n_lags=100):

    def plot_cf(ax, fn, data, n_lags):
        """
        Plot autocorrelation functions for the loads
        """
        fn(data, ax=ax, lags=n_lags, color="#0504aa")
        for i in range(1, 5):
            ax.axvline(x=24*i, ymin=0.0, ymax=1.0, color='grey', ls="--")    

    # AD Fuller test and linear trend of the time series
    trend = TargetTransformer.get_trend(data)
    adf = adfuller(data)
            
    fig, axs = plt.subplots(2, 2, figsize=(25, 12))
    axs = axs.flat
    
    # original time series
    axs[0].plot(data, color='#0504aa')
    axs[0].plot(trend, color="red")
    axs[0].set(xlabel="Date", ylabel="KWh", 
               title=f"Energy consumption over time (ADF p-value: {round(adf[1], 6)})")
        
    # histogram of value distribution
    axs[1].hist(data, bins=200, width = 3, color='#0504aa',alpha=0.7)
    axs[1].set(xlabel="KWh", ylabel="# data points", title="Energy values distribution")
    
    # autocorrelation function
    plot_cf(axs[2], plot_acf, data, n_lags)
    axs[2].set(xlabel="lag", ylabel="ACF value")
    
    # partial autocorrelation function
    plot_cf(axs[3], plot_pacf, data, n_lags)
    axs[3].set(xlabel="lag", ylabel="PACF value")
    
    plt.show()

# %%
ts_analysis_plots(data_fotovolt["energy"],100)
# Out:
# C:\Users\Stefan\Documents\SSNOMBACTER\pyproj\my_env\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from sklearn.metrics import make_scorer

# MAPE computation
def mape(y, yhat, perc=True):
    n = len(yhat.index) if type(yhat) == pd.Series else len(yhat)    
    mape = []
    for a, f in zip(y, yhat):
        # avoid division by 0
        if f > 1e-9:
            mape.append(np.abs((a - f)/a))
    mape = np.mean(np.array(mape))
    return mape * 100. if perc else mape

mape_scorer = make_scorer(mape, greater_is_better=False)

# %%
# the complete time series



c_target_carbune = data_carbune["energy"] 
c_target_hidro = data_hidro["energy"] 
c_target_hidrocarburi = data_hidrocarburi["energy"]
c_target_nuclear = data_nuclear["energy"] 
c_target_eolian = data_eolian["energy"] 
c_target_fotovolt = data_fotovolt["energy"] 
c_target_biomasa = data_biomasa["energy"]
c_target_sold = data_sold["energy"] 

c_target_productie = data_productie["energy"] 
c_target_consum = data_consum["energy"]

# %%
def create_lag_features(target, lags=None, thres=0.2):
    
    scaler = StandardScaler()
    features = pd.DataFrame()
                
    if lags is None:
        partial = pd.Series(data=pacf(target, nlags=48))
        lags = list(partial[np.abs(partial) >= thres].index)

    df = pd.DataFrame()
    if 0 in lags:
        lags.remove(0) # do not consider itself as lag feature
    for l in lags:
        df[f"lag_{l}"] = target.shift(l)
        
    features = pd.DataFrame(scaler.fit_transform(df[df.columns]), 
                            columns=df.columns)

    features = df
    features.index = target.index
    
    return features

def create_ts_features(data):
    

    
    features = pd.DataFrame()
    
    features["weekday"] = data.index.weekday
    features["dayofyear"] = data.index.dayofyear
    features["is_weekend"] = data.index.weekday.isin([5, 6]).astype(np.int32)
    features["weekofyear"] = data.index.weekofyear
    features["month"] = data.index.month
    features["season"] = (data.index.month%12 + 3)//3
    features["target"]=data.values

    


    features.index = data.index
        
    return features

# %%
lags_carbune = create_lag_features(c_target_carbune, thres=0.2)
ts_carbune = create_ts_features(c_target_carbune)
features_carbune = ts_carbune.join(lags_carbune, how="outer").dropna()
target_carbune = c_target_carbune[c_target_carbune.index >= features_carbune.index[0]]
features_carbune=features_carbune.drop_duplicates()
###
# Out:
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_7232\3527084340.py:33: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series. To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   features["weekofyear"] = data.index.weekofyear

# %%
lags_hidro = create_lag_features(c_target_hidro, thres=0.2)
ts_hidro = create_ts_features(c_target_hidro)
features_hidro = ts_hidro.join(lags_hidro, how="outer").dropna()
target_hidro = c_target_hidro[c_target_hidro.index >= features_hidro.index[0]]
features_hidro=features_hidro.drop_duplicates()
###
# Out:
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_7232\3527084340.py:33: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series. To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   features["weekofyear"] = data.index.weekofyear

# %%
lags_hidrocarburi = create_lag_features(c_target_hidrocarburi, thres=0.2)
ts_hidrocarburi = create_ts_features(c_target_hidrocarburi)
features_hidrocarburi = ts_hidrocarburi.join(lags_hidrocarburi, how="outer").dropna()
target_hidrocarburi = c_target_hidrocarburi[c_target_hidrocarburi.index >= features_hidrocarburi.index[0]]
features_hidrocarburi=features_hidrocarburi.drop_duplicates()
###
# Out:
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_7232\3527084340.py:33: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series. To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   features["weekofyear"] = data.index.weekofyear

# %%
lags_nuclear = create_lag_features(c_target_nuclear, thres=0.2)
ts_nuclear = create_ts_features(c_target_nuclear)
features_nuclear = ts_nuclear.join(lags_nuclear, how="outer").dropna()
target_nuclear = c_target_nuclear[c_target_nuclear.index >= features_nuclear.index[0]]
features_nuclear=features_nuclear.drop_duplicates()
###
# Out:
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_7232\3527084340.py:33: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series. To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   features["weekofyear"] = data.index.weekofyear

# %%
lags_eolian = create_lag_features(c_target_eolian, thres=0.2)
ts_eolian = create_ts_features(c_target_eolian)
features_eolian = ts_eolian.join(lags_eolian, how="outer").dropna()
target_eolian = c_target_eolian[c_target_eolian.index >= features_eolian.index[0]]
features_eolian=features_eolian.drop_duplicates()
###
# Out:
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_9308\3527084340.py:33: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series. To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   features["weekofyear"] = data.index.weekofyear

# %%
lags_fotovolt = create_lag_features(c_target_fotovolt, thres=0.2)
ts_fotovolt = create_ts_features(c_target_fotovolt)
features_fotovolt = ts_fotovolt.join(lags_fotovolt, how="outer").dropna()
target_fotovolt = c_target_fotovolt[c_target_fotovolt.index >= features_fotovolt.index[0]]
features_fotovolt=features_fotovolt.drop_duplicates()
###
# Out:
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_9308\3527084340.py:33: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series. To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   features["weekofyear"] = data.index.weekofyear

# %%
lags_biomasa = create_lag_features(c_target_biomasa, thres=0.2)
ts_biomasa = create_ts_features(c_target_biomasa)
features_biomasa = ts_biomasa.join(lags_biomasa, how="outer").dropna()
target_biomasa = c_target_biomasa[c_target_biomasa.index >= features_biomasa.index[0]]
features_biomasa=features_biomasa.drop_duplicates()
# Out:
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_14748\3527084340.py:33: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series. To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   features["weekofyear"] = data.index.weekofyear

# %%
lags_sold = create_lag_features(c_target_sold, thres=0.2)
ts_sold = create_ts_features(c_target_sold)
features_sold = ts_sold.join(lags_sold, how="outer").dropna()
target_sold = c_target_sold[c_target_sold.index >= features_sold.index[0]]
features_sold=features_sold.drop_duplicates()
# Out:
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_14748\3527084340.py:33: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series. To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   features["weekofyear"] = data.index.weekofyear

# %%
lags_productie = create_lag_features(c_target_productie, thres=0.2)
ts_productie = create_ts_features(c_target_productie)
features_productie = ts_productie.join(lags_productie, how="outer").dropna()
target_productie = c_target_productie[c_target_productie.index >= features_productie.index[0]]
features_productie=features_productie.drop_duplicates()
# Out:
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_14748\3527084340.py:33: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series. To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   features["weekofyear"] = data.index.weekofyear

# %%
lags_consum = create_lag_features(c_target_consum, thres=0.2)
ts_consum = create_ts_features(c_target_consum)
features_consum = ts_consum.join(lags_consum, how="outer").dropna()
target_consum = c_target_consum[c_target_consum.index >= features_consum.index[0]]
features_consum=features_consum.drop_duplicates()
# Out:
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_14748\3527084340.py:33: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series. To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   features["weekofyear"] = data.index.weekofyear

# %%
target_carbune=features_carbune.target#
features_carbune=features_carbune.drop('target',axis=1)

# %%
target_hidro=features_hidro.target#
features_hidro=features_hidro.drop('target',axis=1)

# %%
target_hidrocarburi=features_hidrocarburi.target#
features_hidrocarburi=features_hidrocarburi.drop('target',axis=1)

# %%
target_nuclear=features_nuclear.target#
features_nuclear=features_nuclear.drop('target',axis=1)

# %%
target_eolian=features_eolian.target#
features_eolian=features_eolian.drop('target',axis=1)

# %%
target_fotovolt=features_fotovolt.target#
features_fotovolt=features_fotovolt.drop('target',axis=1)

# %%
target_biomasa=features_biomasa.target
features_biomasa=features_biomasa.drop('target',axis=1)

# %%
target_sold=features_sold.target
features_sold=features_sold.drop('target',axis=1)#degeaba asta

# %%
target_productie=features_productie.target
features_productie=features_productie.drop('target',axis=1)

# %%
target_consum=features_consum.target
features_consum=features_consum.drop('target',axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(features_carbune, #
                                                    target_carbune, 
                                                    test_size=0.3,
                                                    shuffle=False)

# %%
X_train, X_test, y_train, y_test = train_test_split(features_hidro, #
                                                    target_hidro, 
                                                    test_size=0.3,
                                                    shuffle=False)

# %%
X_train, X_test, y_train, y_test = train_test_split(features_hidrocarburi, #
                                                    target_hidrocarburi, 
                                                    test_size=0.3,
                                                    shuffle=False)

# %%
X_train, X_test, y_train, y_test = train_test_split(features_nuclear, #
                                                    target_nuclear, 
                                                    test_size=0.3,
                                                    shuffle=False)

# %%
X_train, X_test, y_train, y_test = train_test_split(features_eolian, #
                                                    target_eolian, 
                                                    test_size=0.3,
                                                    shuffle=False)

# %%
X_train, X_test, y_train, y_test = train_test_split(features_fotovolt, #
                                                    target_fotovolt, 
                                                    test_size=0.3,
                                                    shuffle=False)

# %%
X_train, X_test, y_train, y_test = train_test_split(features_biomasa, 
                                                    target_biomasa, 
                                                    test_size=0.3,
                                                    shuffle=False)

# %%
X_train, X_test, y_train, y_test = train_test_split(features_sold, #degeaba
                                                    target_sold, 
                                                    test_size=0.3,
                                                    shuffle=False)

# %%
X_train, X_test, y_train, y_test = train_test_split(features_productie, 
                                                    target_productie, 
                                                    test_size=0.3,
                                                    shuffle=False)

# %%
X_train, X_test, y_train, y_test = train_test_split(features_consum, 
                                                    target_consum, 
                                                    test_size=0.3,
                                                    shuffle=False)

# %%
y_test
# Out:
# date
# 2019-06-21      0
# 2019-06-21      0
# 2019-06-21    276
# 2019-06-21    276
# 2019-06-21    276
#              ...
# 2022-04-14    785
# 2022-04-14     84
# 2022-04-14     84
# 2022-04-14     84
# 2022-04-14     84
# Name: target, Length: 11595, dtype: int64

# %%
# Out:
#             weekday  dayofyear  is_weekend  weekofyear  month  season   lag_1  \
# date
# 2019-03-09        5         68           1          10      3       2   137.0
# 2019-03-10        6         69           1          10      3       2   308.0
# 2019-03-11        0         70           0          11      3       2 -1253.0
# 2019-03-12        1         71           0          11      3       2  -254.0
# 2019-03-13        2         72           0          11      3       2  -876.0
# ...             ...        ...         ...         ...    ...     ...     ...
# 2021-04-16        4        106           0          15      4       2  -330.0
# 2021-04-16        4        106           0          15      4       2   765.0
# 2021-04-17        5        107           1          15      4       2   -57.0
# 2021-04-18        6        108           1          15      4       2   422.0
# 2021-04-19        0        109           0          16      4       2    -6.0
#
#              lag_2
# date
# ...

# %%
# run XGBoost algorithm with hyperparameters optimization
# this model outperforms the linear regression

def train_xgb(params, X_train, y_train):
    """
    Train XGBoost regressor using the parameters given as input. The model
    is validated using standard cross validation technique adapted for time series
    data. This function returns a friendly output for the hyperopt parameter optimization
    module.
    
    Parameters
    ----------
    params: dict with the parameters of the XGBoost regressor. For complete list see: 
            https://xgboost.readthedocs.io/en/latest/parameter.html
    X_train: pd.DataFrame with the training set features
    y_train: pd.Series with the training set targets    
    
    Returns
    -------
    dict with keys 'model' for the trained model, 'status' containing the hyperopt
    status string and 'loss' with the RMSE obtained from cross-validation
    """
    
    n_estimators = int(params["n_estimators"])
    max_depth= int(params["max_depth"])

    try:
        model = xgb.XGBRegressor(n_estimators=n_estimators, 
                                 max_depth=max_depth, 
                                 learning_rate=params["learning_rate"],
                                 subsample=params["subsample"])

        result = model.fit(X_train, 
                           y_train.values.ravel(),
                           eval_set=[(X_train, y_train.values.ravel())],
                           early_stopping_rounds=50,
                           verbose=False)
        
        # cross validate using the right iterator for time series
        cv_space = TimeSeriesSplit(n_splits=5)
        cv_score = cross_val_score(model, 
                                   X_train, y_train.values.ravel(), 
                                   cv=cv_space, 
                                   scoring=mape_scorer)

        rmse = np.abs(np.mean(np.array(cv_score)))
        return {
            "loss": rmse,
            "status": STATUS_OK,
            "model": model
        }
        
    except ValueError as ex:
        return {
            "error": ex,
            "status": STATUS_FAIL
        }
    
def optimize_xgb(X_train, y_train, max_evals=10):
    """
    Run Bayesan optimization to find the optimal XGBoost algorithm
    hyperparameters.
    
    Parameters
    ----------
    X_train: pd.DataFrame with the training set features
    y_train: pd.Series with the training set targets
    max_evals: the maximum number of iterations in the Bayesian optimization method
    
    Returns
    -------
    best: dict with the best parameters obtained
    trials: a list of hyperopt Trials objects with the history of the optimization
    """
    
    space = {
        "n_estimators": hp.quniform("n_estimators", 100, 1000, 10),
        "max_depth": hp.quniform("max_depth", 1, 8, 1),
        "learning_rate": hp.loguniform("learning_rate", -5, 1),
        "subsample": hp.uniform("subsample", 0.8, 1),
        "gamma": hp.quniform("gamma", 0, 100, 1)
    }

    objective_fn = partial(train_xgb, 
                           X_train=X_train, 
                           y_train=y_train)
    
    trials = Trials()
    best = fmin(fn=objective_fn,
                space=space,
                algo=tpe.suggest,
                max_evals=max_evals,
                trials=trials)

    # evaluate the best model on the test set
    print(f"""
    Best parameters:
        learning_rate: {best["learning_rate"]} 
        n_estimators: {best["n_estimators"]}
        max_depth: {best["max_depth"]}
        sub_sample: {best["subsample"]}
        gamma: {best["gamma"]}
    """)
    return best, trials

best, trials = optimize_xgb(X_train, y_train, max_evals=50)
# Out:
#   0%|                                                                           | 0/50 [00:00<?, ?trial/s, best loss=?]
# C:\Users\Stefan\Documents\SSNOMBACTER\pyproj\my_env\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
#
# C:\Users\Stefan\Documents\SSNOMBACTER\pyproj\my_env\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
#
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_9308\230559206.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   mape.append(np.abs((a - f)/a))
#
# ...

# %%
# evaluate the best model on the test set
res = train_xgb(best, X_test, y_test)
xgb_model = res["model"]
predictions = xgb_model.predict(X_test)
cv_score = min([f["loss"] for f in trials.results if f["status"] == STATUS_OK])
test_score = mape(y_test.values, predictions)

print(f"Root mean square error cross-validation/test: {cv_score:.4f} / {test_score:.4f}")
# Out:
# C:\Users\Stefan\Documents\SSNOMBACTER\pyproj\my_env\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_9308\230559206.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   mape.append(np.abs((a - f)/a))
# C:\Users\Stefan\Documents\SSNOMBACTER\pyproj\my_env\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_9308\230559206.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   mape.append(np.abs((a - f)/a))
# ...

# %%
# inverse transform
actual = y_test
predictions = pd.Series(data=predictions, index=y_test.index)
#predictions = transformer.inverse(y_test.index, predictions)
#actual = transformer.inverse(y_test.index, y_test.values)

# plot predictions on the test set
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
_ = xgb.plot_importance(xgb_model, height=0.9, ax=ax1)
ax2.plot(actual, label="target", color="blue")
ax2.plot(predictions, label="predicted", color="red")
ax2.set_title("Model predictions on test set")
ax2.legend()
plt.show()

# store the results
xgb_predictions = predictions.copy()

# %%
df = pd.DataFrame(xgb_predictions)
df.to_csv('pred solar.csv')

# %%
df = pd.DataFrame(y_test)
df.to_csv('actual solar.csv')

# %%
plt.hist(actual, bins =50,label='actual solar')
plt.hist(predictions, bins =50,label='predicted solar')
plt.legend()

# %%
predictions
# Out:
# date
# 2017-05-13    2512.709717
# 2017-05-13    2610.414307
# 2017-05-13    2705.505371
# 2017-05-13    2512.709717
# 2017-05-13    2610.414307
#                  ...
# 2022-04-14    1992.689331
# 2022-04-14    2087.274902
# 2022-04-14    2036.663452
# 2022-04-14    2004.709717
# 2022-04-14    1992.689331
# Length: 26861, dtype: float32

# %%
from xgboost import plot_importance

# %%
print(actual.mean())
print(np.std(actual))
print(skew(actual))
print(kurtosis(actual))
print(variation(actual))
print(actual.min())
print(actual.max())
# Out:
# 203.01768003449763
# 238.10889616245487
# 0.88605953773402
# -0.5633881373803793
# 1.1728480796450556
# 0
# 862

# %%
print(predictions.mean())
print(np.std(predictions))
print(skew(predictions))
print(kurtosis(predictions))
print(variation(predictions))
print(predictions.min())
print(predictions.max())
# Out:
# 202.97855
# 77.84917
# 0.028651558137133427
# -0.28301475250982566
# 0.383534
# 22.311403
# 500.05966
